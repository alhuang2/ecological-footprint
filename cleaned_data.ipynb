# %%
import pandas as pd
import numpy as np

df = pd.read_csv('NFA_2018.csv', usecols=[0,1,4,5,12])

EFCons = df[df.record == 'EFConsPerCap']


years = [1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]

EFCons_years = EFCons[EFCons.year.isin(years)]

EFCons_years

EFCons_clean = EFCons_years[EFCons_years.country != 'World']

EFCons_clean
# Out:
#            country ISO alpha-3 code  year        record      total
# 22         Armenia              ARM  1994  EFConsPerCap   1.115877
# 32         Armenia              ARM  1995  EFConsPerCap   1.028198
# 42         Armenia              ARM  1996  EFConsPerCap   1.038000
# 52         Armenia              ARM  1997  EFConsPerCap   1.108374
# 62         Armenia              ARM  1998  EFConsPerCap   1.153641
# 72         Armenia              ARM  1999  EFConsPerCap   1.146431
# 82         Armenia              ARM  2000  EFConsPerCap   1.144260
# 92         Armenia              ARM  2001  EFConsPerCap   1.223878
# 102        Armenia              ARM  2002  EFConsPerCap   1.235047
# 112        Armenia              ARM  2003  EFConsPerCap   1.267316
# 122        Armenia              ARM  2004  EFConsPerCap   1.443231
# 132        Armenia              ARM  2005  EFConsPerCap   1.582594
# 142        Armenia              ARM  2006  EFConsPerCap   1.586752
# 152        Armenia              ARM  2007  EFConsPerCap   1.887147
# 162        Armenia              ARM  2008  EFConsPerCap   2.239563
# 172        Armenia              ARM  2009  EFConsPerCap   1.939838
# 182        Armenia              ARM  2010  EFConsPerCap   1.865160
# 192        Armenia              ARM  2011  EFConsPerCap   2.062219
# 202        Armenia              ARM  2012  EFConsPerCap   2.139383
# 212        Armenia              ARM  2013  EFConsPerCap   2.033198
# 222        Armenia              ARM  2014  EFConsPerCap   2.018595
# 562    Afghanistan              AFG  1994  EFConsPerCap   0.664134
# 572    Afghanistan              AFG  1995  EFConsPerCap   0.657660
# 582    Afghanistan              AFG  1996  EFConsPerCap   0.679087
# 592    Afghanistan              AFG  1997  EFConsPerCap   0.706724
# 602    Afghanistan              AFG  1998  EFConsPerCap   0.725714
# 612    Afghanistan              AFG  1999  EFConsPerCap   0.736066
# 622    Afghanistan              AFG  2000  EFConsPerCap   0.648085
# 632    Afghanistan              AFG  2001  EFConsPerCap   0.605820
# 642    Afghanistan              AFG  2002  EFConsPerCap   0.704061
# ...            ...              ...   ...           ...        ...
# 85522        China              CHN  1997  EFConsPerCap   1.892439
# 85532        China              CHN  1998  EFConsPerCap   1.927881
# 85542        China              CHN  1999  EFConsPerCap   1.907186
# 85552        China              CHN  2000  EFConsPerCap   1.946163
# 85562        China              CHN  2001  EFConsPerCap   1.998151
# 85572        China              CHN  2002  EFConsPerCap   2.082236
# 85582        China              CHN  2003  EFConsPerCap   2.231896
# 85592        China              CHN  2004  EFConsPerCap   2.474796
# 85602        China              CHN  2005  EFConsPerCap   2.622728
# 85612        China              CHN  2006  EFConsPerCap   2.769283
# 85622        China              CHN  2007  EFConsPerCap   2.906292
# 85632        China              CHN  2008  EFConsPerCap   2.996137
# 85642        China              CHN  2009  EFConsPerCap   3.230869
# 85652        China              CHN  2010  EFConsPerCap   3.404740
# 85662        China              CHN  2011  EFConsPerCap   3.585563
# 85672        China              CHN  2012  EFConsPerCap   3.634253
# 85682        China              CHN  2013  EFConsPerCap   3.740306
# 85692        China              CHN  2014  EFConsPerCap   3.709965
# 86572      Belgium              BEL  1994  EFConsPerCap   6.928670
# 86582      Belgium              BEL  1995  EFConsPerCap   7.033590
# 86592      Belgium              BEL  1996  EFConsPerCap   7.320013
# 86602      Belgium              BEL  1997  EFConsPerCap   7.292340
# 86612      Belgium              BEL  1998  EFConsPerCap   7.626827
# 86622      Belgium              BEL  1999  EFConsPerCap   7.324239
# 86962   Luxembourg              LUX  1994  EFConsPerCap  14.106754
# 86972   Luxembourg              LUX  1995  EFConsPerCap  13.682908
# 86982   Luxembourg              LUX  1996  EFConsPerCap  14.196521
# 86992   Luxembourg              LUX  1997  EFConsPerCap  15.194159
# 87002   Luxembourg              LUX  1998  EFConsPerCap  13.984384
# 87012   Luxembourg              LUX  1999  EFConsPerCap  15.447996
#
# [3789 rows x 5 columns]
